# %%
budget = int(input("Enter your budget: "))
source = input("Enter your source: ")
destination = input("Enter your destination: ")

if budget >= 50000:
    print("Travel booking is available")
    print("From", source, "to", destination)
else:
    print("Sorry, your budget is too low")
# Out:
# Enter your budget: 10000
# Enter your source: Karachi
# Enter your destination: Lahore
# Sorry, your budget is too low
