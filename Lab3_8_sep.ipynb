# %% [markdown]
# <a href="https://colab.research.google.com/github/KiranNaseer22/Kiran-23122210-lab1-Ai-6A/blob/main/Lab3_8_sep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="")


MODEL = "models/gemini-3.5-flash"


def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1. Destination Overview
2. Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3. Places to Visit (specific locations)
4. Food Suggestions (local dishes)
5. Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# ...
# Gemini Travel Agent Started (type 'exit' to stop)
#
# You: OK
# WARNING:google_genai.models:Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Error: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# You: Exit
# Goodbye

# %%
def library_assistant(user_input):

    prompt = f"""
You are a Library Assistant Agent.

Help students with their library needs.

You can help them:
1. Find books
2. Suggest books
3. Check book availability
4. Give information about borrowing and returning books

Give simple and clear answers.

User request: {user_input}

Library Assistant:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Library Assistant Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye")
        break

    try:
        reply = library_assistant(user)
        print("\nLibrary Assistant:\n", reply, "\n")
    except Exception as e:
        print("Error:", e)
# Out:
# Library Assistant Agent Started (type 'exit' to stop)
#
# You: Suggest me a book for learning python
#
# Library Assistant:
#  Here are two great books for learning Python:
#
# 1. **"Python Crash Course" by Eric Matthes** - This is a wonderful, hands-on guide for beginners. It teaches you the basics before leading you through fun projects like making games and data visualizations.
# 2. **"Automate the Boring Stuff with Python" by Al Sweigart** - Great for practical learning. It teaches you how to use Python to write simple programs that do practical tasks on your computer.
#
# Would you like me to check if these books are currently available to borrow?
#
# You: Exit
# Goodbye
